# %%
from pyquery import PyQuery as pq
import pandas as pd 
import requests

# %%
link = 'http://www.mc.rs/stampani-mediji---dnevne-novine-nedeljnici-magazini.16.html'
page_req = requests.get(link)

page_ = pq(page_req.text)

page_right = page_('div#contentRight')

# %%
page_right()
# Out:
# u'\r\n\t\t\t\t<div id="crumbs"><a href="/dobrodosli.806.html" title="Po\u010detna">Po\u010detna</a>\xa0&gt;\xa0<a href="/mediji-o-medijima.6.html" title="MC za medije">MC za medije</a>\xa0&gt;\xa0<a href="/mc-adresar---mediji-u-beogradu-mediji-u-srbiji-mediji-u-regionu-mediji-u-dijaspori.1688.html" title="Adresari">Adresari</a>\xa0&gt;\xa0<a href="/stampani-mediji---dnevne-novine-nedeljnici-magazini.16.html" title="\u0160tampani mediji - dnevne novine, nedeljnici, magazini"><strong>\u0160tampani mediji - dnevne novine, nedeljnici, magazini</strong></a></div>&#13;\n\t\t\t\t<!-- OCP content start -->&#13;\n                <a id="198380"></a><div class="block">&#13;\n\t<h1>MC adresar</h1>&#13;\n\t<div class="image_holder left">&#13;\n\t\t<img src="/upload/images/Adresari/stampa.gif" />&#13;\n\t</div>&#13;\n\t<div></div>&#13;\n</div><a id="198382"></a>&#13;\n\t\t<div class="block select_block">&#13;\n\t\t    <!-- <h4><VersionLabels.Get(Page, "select_block_title")></h4> -->&#13;\n\t\t    <select onchange="window.open(this.value, \'_self\');">&#13;\n\t\t        <option value="">Izaberite naslov</option>&#13;\n\t\t\t&#13;\n\t\t\t\t        <option value="#198380">MC adresar</option>&#13;\n\t\t\t&#13;\n\t\t\t\t        <option value="#198383">Beograd</option>&#13;\n\t\t\t&#13;\n\t\t\t\t        <option value="#198388">Srbija</option>&#13;\n\t\t\t&#13;\n\t\t\t\t        <option value="#198391">Region</option>&#13;\n\t&#13;\n            </select>&#13;\n        </div>&#13;\n<a id="198383"></a><div class="block">&#13;\n\t<h1>Beograd</h1>&#13;\n\t<div><p>\xa0 </p></div>&#13;\n</div><a id="198384"></a><div class="block">&#13;\n\t<div class="image_holder Right">&#13;\n\t\t<img src="/upload/images/Adresari/novine.jpg" class="image_border" />&#13;\n\t</div>&#13;\n\t<div><strong><font color="#0076a0">DNEVNE NOVINE</font></strong> <br /><br /><p><strong>ALO!<br /></strong><a href="http://www.alo.rs/" target="_blank">www.alo.rs</a><br />Ringier Axel Springer d.o.o.<br />\u017dor\u017ea Klemansoa 19, Beograd<br />Dejan Vukeli\u0107, glavni i odgovorni urednik<br />Tel: 011/ 2020 120<br />Faks: 011/ 2020 121<br />E-mail: <a href="mailto:redakcija@alo.rs" target="">redakcija@alo.rs</a>, <a href="mailto:online@alo.rs" target="">online@alo.rs</a></p></div>&#13;\n</div><a id="198385"></a>&#13;\n&#13;\n&#13;\n<!-- saved from url=(0022)http://internet.e-mail -->&#13;\n  <style type="text/css">&#13;\np {\xa0padding: 0px; margin: 0px; margin-bottom: 12px; line-height: 14pt\xa0}&#13;\n.style6 {color: #006699}&#13;\n  </style>&#13;\n&#13;\n&#13;\n&#13;\n&#13;\n<table border="0" width="100%">&#13;\n&#13;\n  <tbody>&#13;\n    <tr>&#13;\n&#13;\n\t<td style="font-size: 12px;" valign="top">&#13;\n      <p><strong>24 SATA</strong><br />&#13;\n&#13;\n      <a href="http://www.24sata.rs/" target="_blank" class="style6">www.24sata.rs</a><br />&#13;\n&#13;\nRingier Axel Springer d.o.o.<br />&#13;\n\u017dor\u017ea Klemansoa 19, Beograd<br />&#13;\n&#13;\nGoran Gavranovi\u0107, glavni urednik<br />&#13;\nJelena Tu\u0161up, odgovorni urednik sajta 24 sata<br />&#13;\n&#13;\nTel: 011/ 333 4 555 <br />&#13;\n&#13;\nFax:   011/ 333 4 556<br />&#13;\n&#13;\nE-mail: <a href="mailto:redakcija@24sata.rs" target="_blank" class="style6">redakcija@24sata.rs</a>, <a href="mailto:redakcija_24sata@ringier.rs" target="_blank" class="style6">redakcija_24sata@ringier.rs</a> </p>&#13;\n&#13;\n    &#13;\n      <p><strong>BLIC</strong><br />&#13;\n&#13;\n        <a href="http://www.blic.rs/" target="_blank" class="style6">www.blic.rs</a><br />&#13;\n        Ringier Axel Springer d.o.o.<br />&#13;\n        \u017dor\u017ea Klemansoa 19, Beograd<br />&#13;\n&#13;\n      Marko Stjepanovi\u0107, glavni i ogovorni urednik<br />&#13;\n&#13;\n      Tel: 011/ 333 4 559, 333 4 555, 333 4   701<br />&#13;\n&#13;\n      Fax: 011/ 333 4 556<br />&#13;\n&#13;\n  <a href="mailto:redakcija@blic.rs" target="_blank" class="style6">redakcija@blic.rs</a> </p>&#13;\n&#13;\n    &#13;\n      <p><strong>DANAS</strong ...
